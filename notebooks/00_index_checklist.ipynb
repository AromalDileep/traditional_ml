# %% [markdown]
# # Machine Learning Revision Checklist (Start → Finish)
#
# ---
#
# ## 1. Python Fundamentals (ML-Only)
# - [-] Variables & data types
# - [-] Lists, tuples, sets, dictionaries
# - [-] Loops (`for`, `while`)
# - [-] Conditional statements
# - [-] Functions
# - [-] Lambda functions
# - [-] List / dict comprehensions
# - [-] `zip`, `enumerate`
# - [-] `*args`, `**kwargs`
# - [-] Basic file handling (`csv`, `json`)
# - [-] `collections.Counter`
#
# ---
#
# ## 2. NumPy (Core Data Handling)
# - [-] Import NumPy
# - [-] `ndarray` vs Python list
# - [-] Array creation (`zeros`, `ones`, `arange`, `linspace`)
# - [-] Random arrays (`rand`, `randn`)
# - [-] Shape, dtype
# - [-] Reshape
# - [-] Indexing & slicing
# - [-] Boolean masking
# - [-] Broadcasting
# - [-] Vectorized operations
# - [-] Aggregations (`sum`, `mean`, `std`)
# - [-] Axis concept (`axis=0`, `axis=1`)
# - [-] Dot product
# - [-] Simple normalization using NumPy
#
# ---
#
# ## 3. Pandas (Real-World Data)
# - [-] Import Pandas
# - [-] `Series` vs `DataFrame`
# - [-] Load CSV / Excel
# - [-] `head`, `tail`, `info`, `describe`
# - [-] Column selection
# - [-] Row filtering
# - [-] `loc` vs `iloc`
# - [-] Sorting
# - [-] Handling missing values
# - [-] Type conversion (`astype`)
# - [-] Categorical data handling
# - [-] `groupby` + `agg`
# - [-] Merging & joining
# - [-] One-hot encoding (`get_dummies`)
# - [-] Train/test data preparation
#
# ---
#
# ## 4. Data Visualization (EDA)
# - [-] Import Matplotlib
# - [-] Import Seaborn
# - [-] Line plot
# - [-] Scatter plot
# - [-] Histogram
# - [-] Box plot
# - [-] Bar plot
# - [-] Count plot
# - [-] Correlation heatmap
# - [-] Outlier visualization
# - [-] Feature vs target plots
#
# ---
#
# ## 5. ML Problem Types
# - [-] Supervised learning
# - [-] Unsupervised learning
# - [-] Regression vs Classification
# - [-] Clustering vs Classification
# - [-] Batch learning vs online learning
#
# ---
#
# ## 6. Scikit-Learn Basics
# - [-] Install & import scikit-learn
# - [-] Dataset loading (`sklearn.datasets`)
# - [-] `train_test_split`
# - [-] Fit / predict workflow
# - [-] Model object lifecycle
# - [-] Reproducibility (`random_state`)
#
# ---
#
# ## 7. Data Preprocessing
# - [-] Train/test split BEFORE preprocessing
# - [-] Feature scaling
# - [-] StandardScaler
# - [-] MinMaxScaler
# - [-] Label encoding
# - [-] One-hot encoding
# - [-] Handling missing values
# - [-] Feature transformation
# - [-] Using `Pipeline`
# - [-] Using `ColumnTransformer`
#
# ---
#
# ## 8. Regression Algorithms
# - [-] Linear Regression
# - [-] Ridge Regression
# - [-] Lasso Regression
# - [-] ElasticNet
# - [-] Compare regression models
# - [-] Understand overfitting in regression
#
# ---
#
# ## 9. Classification Algorithms
# - [-] Logistic Regression
# - [-] K-Nearest Neighbors (KNN)
# - [-] Decision Tree
# - [-] Random Forest
# - [-] Support Vector Machine (SVM)
# - [ ] Naive Bayes
# - [ ] Compare classification models
#
# ---
#
# ## 10. Unsupervised Learning
# - [ ] K-Means clustering
# - [ ] Choosing `k` (Elbow method)
# - [ ] DBSCAN (concept + use case)
# - [ ] Hierarchical clustering (concept)
# - [ ] PCA (dimensionality reduction)
# - [ ] PCA + ML pipeline
#
# ---
#
# ## 11. Model Evaluation
# - [ ] Train vs test accuracy
# - [ ] Confusion matrix
# - [ ] Accuracy
# - [ ] Precision
# - [ ] Recall
# - [ ] F1-score
# - [ ] ROC curve (concept)
# - [ ] ROC-AUC (concept)
# - [ ] Regression metrics (MAE, MSE, RMSE, R²)
# - [ ] Cross-validation
#
# ---
#
# ## 12. Hyperparameters & Tuning
# - [ ] Model parameters vs hyperparameters
# - [ ] GridSearchCV
# - [ ] RandomizedSearchCV
# - [ ] Overfitting detection
# - [ ] Bias-variance tradeoff (intuition)
#
# ---
#
# ## 13. Feature Engineering
# - [ ] Scaling vs normalization
# - [ ] Encoding categorical features
# - [ ] Feature selection intuition
# - [ ] Removing irrelevant features
# - [ ] Feature interaction (basic)
# - [ ] Curse of dimensionality (intuition)
#
# ---
#
# ## 14. Common ML Pitfalls (MUST KNOW)
# - [ ] Data leakage
# - [ ] Overfitting vs underfitting
# - [ ] Why trees don’t need scaling
# - [ ] Why KNN & SVM need scaling
# - [ ] Imbalanced datasets
# - [ ] Why accuracy can be misleading
#
# ---
#
# ## 15. End-to-End ML Project (FINAL STEP)
# - [ ] Choose dataset
# - [ ] Load & inspect data
# - [ ] EDA
# - [ ] Preprocessing
# - [ ] Feature engineering
# - [ ] Train multiple models
# - [ ] Evaluate & compare
# - [ ] Final model selection
# - [ ] Clean notebook with markdown explanations
#
# ---
#
# ## 🎯 Final Goal
# - [ ] I can build an end-to-end traditional ML pipeline confidently
# - [ ] I can explain model choices and results clearly
# - [ ] I am ready to add mathematics later
