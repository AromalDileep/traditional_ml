# %% [markdown]
# # 00 — Environment Setup & Conventions
#
# ## Purpose
# This notebook defines the **baseline environment, imports, and conventions**
# used across the entire *Traditional Machine Learning* revision.
#
# Goals:
# - Ensure reproducibility
# - Centralize imports
# - Set consistent display and plotting behavior
# - Avoid repeated setup code in later notebooks
#
# All subsequent notebooks assume this setup.

# %%
# Core numerical & data libraries
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn utilities
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Why Centralized Imports?
#
# - Avoids repeating boilerplate in every notebook
# - Keeps later notebooks focused on concepts
# - Makes environment expectations explicit
#
# If a new library is required later, it should be:
# - Added **only if necessary**
# - Justified in that notebook

# %%
import sys
import sklearn

print("Python version :", sys.version)
print("NumPy version  :", np.__version__)
print("Pandas version :", pd.__version__)
print("Scikit-learn  :", sklearn.__version__)
# Out:
# Python version : 3.11.14 (main, Oct 21 2025, 18:31:21) [GCC 11.2.0]
# NumPy version  : 2.3.5
# Pandas version : 2.3.3
# Scikit-learn  : 1.8.0

# %% [markdown]
# ## Random Seed Policy
#
# To ensure reproducibility:
# - A fixed random seed is used where applicable
# - Especially important for:
#   - Train/test split
#   - Randomized models
#   - Cross-validation
#
# Note:
# Not all algorithms are fully deterministic.

# %%
RANDOM_STATE = 42

np.random.seed(RANDOM_STATE)

# %%
# Later notebooks wii consistently use
random_state=RANDOM_STATE

# %% [markdown]
# ## Display & Plotting Conventions
#
# These settings improve readability:
# - Wider DataFrame display
# - Consistent plotting style
# - Larger default figure size

# %%
# Pandas display options
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", 120)

# Matplotlib & Seaborn settings
plt.style.use("default")
sns.set_theme(style="whitegrid")

plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.titlesize"] = 12
plt.rcParams["axes.labelsize"] = 10

# %% [markdown]
# ## Project Conventions
#
# - All datasets are read from `data/`
# - Raw data is **never modified**
# - Processed data is saved to `data/processed/`
# - Models are saved to `models/saved/`
# - Figures are saved to `outputs/figures/`
#
# No hardcoded absolute paths.
# Relative paths only.

# %%
# Example (for reference only)

# df = pd.read_csv("../data/raw/dataset.csv")
# df.to_csv("../data/processed/dataset_clean.csv", index=False)
# plt.savefig("../outputs/figures/example_plot.png")

# %% [markdown]
# ## Notebook Discipline Rules
#
# These rules apply to all notebooks:
#
# - One notebook = one topic
# - No copy–paste across notebooks
# - Reusable logic goes into `utils/`
# - Each notebook must include:
#   - Explanation
#   - Code
#   - Key takeaways
#
# This is intentional and non-negotiable.
